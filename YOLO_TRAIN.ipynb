# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd Yolov5_DeepSort_Pytorch
# Out:
# /content/Yolov5_DeepSort_Pytorch/Yolov5_DeepSort_Pytorch/Yolov5_DeepSort_Pytorch

# %%
# !pip install pyyaml tqdm
# !pip install torch torchvision torchaudio
# !pip install opencv-python-headless numpy filterpy scikit-image lap
# !pip install yolov5

# %%
# %cd /content/Yolov5_DeepSort_Pytorch/Yolov5_DeepSort_Pytorch/Yolov5_DeepSort_Pytorch

# !python track.py \
  --yolo-model /content/yolov8n.pt \
  --source /content/input.mp4 \
  --save-vid \
  --tracker deep_sort
# Out:
# /content/Yolov5_DeepSort_Pytorch/Yolov5_DeepSort_Pytorch/Yolov5_DeepSort_Pytorch
# python3: can't open file '/content/Yolov5_DeepSort_Pytorch/Yolov5_DeepSort_Pytorch/Yolov5_DeepSort_Pytorch/track.py': [Errno 2] No such file or directory

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 75.4MB/s]

# %%
yaml_text = """
train: /content/kitti_dataset/training/images
val: /content/kitti_dataset/val/images
nc: 1
names: ['car']
"""

with open("/content/kitti_dataset/kitti.yaml", "w") as f:
    f.write(yaml_text)

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
print("GPU name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# CUDA available: False
# GPU name: No GPU

# %%
model.train(
    data="/content/kitti_dataset/kitti.yaml",
    epochs=100,
    imgsz=640,
    freeze=10
)
# Out:
# Ultralytics 8.3.127 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !cp /content/runs/detect/train/weights/best.pt /content/drive/MyDrive/

# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")
model.predict(source="/content/sample.mp4", save=True, conf=0.2)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
